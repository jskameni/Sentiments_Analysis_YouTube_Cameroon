# %% [markdown]
# <a href="https://colab.research.google.com/github/jskameni/Sentiments_Analysis_YouTube_Cameroon/blob/main/Analyse_des_sentiments_Cameroun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries (if not already installed)
# !pip install emoji
# !pip install vaderSentiment-fr
# !pip install google-api-python-client

from googleapiclient.discovery import build
import re
import emoji
from vaderSentiment_fr.vaderSentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, timedelta


# Replace with your actual API key
API_KEY = 'Your_API_Key' # Put in your API Key

youtube = build('youtube', 'v3', developerKey=API_KEY)

# Load channel data
try:
  df_channels = pd.read_csv('CameroonNewsChannels.csv')
except FileNotFoundError:
  print("Error: CameroonNewsChannels.csv not found.")
  exit()


def get_comments_for_video(video_id, uploader_channel_id, channel_name, channel_category):
    print(f"Fetching Comments for video: {video_id}")
    comments_data = []
    nextPageToken = None
    while True:
        request = youtube.commentThreads().list(
            part='snippet',
            videoId=video_id,
            maxResults=100,
            pageToken=nextPageToken
        )
        try:
            response = request.execute()
        except Exception as e:
            print(f"Error fetching comments for {video_id}: {e}")
            return []  # Return an empty list in case of error
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            if comment['authorChannelId']['value'] != uploader_channel_id:
                comments_data.append([channel_id, channel_name, channel_category, comment['textDisplay']])
        nextPageToken = response.get('nextPageToken')
        if not nextPageToken:
            break
    return comments_data

# Calculate the date 8 days ago
three_days_ago = (datetime.now() - timedelta(days=8)).strftime('%Y-%m-%dT%H:%M:%SZ')

all_comments = []
for index, row in df_channels.iterrows():
    channel_id = row['Channel_Id']
    channel_name = row['Channel_Name']
    channel_category = row['Channel_Category']

    request = youtube.search().list(
        part="snippet",
        channelId=channel_id,
        maxResults=50, # Adjust as needed
        publishedAfter=three_days_ago,
        type="video"
    )

    response = request.execute()

    for item in response.get("items", []):
        video_id = item["id"]["videoId"]
        uploader_id = item['snippet']['channelId']  # Get uploader's channel ID
        comments = get_comments_for_video(video_id, uploader_id, channel_name, channel_category)
        all_comments.extend(comments)



print(all_comments)

# Create a DataFrame
df_all_comments = pd.DataFrame(all_comments, columns=['Channel_Id', 'Channel_Name', 'Channel_Category', 'Comment'])

# Pie chart of comment percentage by channel name
channel_comment_counts = df_all_comments.groupby('Channel_Category')['Comment'].count()
plt.figure(figsize=(10, 8))
plt.pie(channel_comment_counts, labels=channel_comment_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Comments by Channel Category')
plt.show()

# Bar chart of comment counts by channel name
plt.figure(figsize=(10, 6))
channel_comment_counts.plot(kind='bar')
plt.xlabel('Channel Category')
plt.ylabel('Number of Comments')
plt.title('Number of Comments per Channel Category')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
import re

def traduire_argot_en_francais(texte):
    correspondances = {
        "répé": "Âgé", "rémé": "Âgé",
        "ya mo": "Aimer",
        "bro": "Ami", "combi": "Ami", "tatat": "Ami", "ndolè": "Ami", "pot": "Ami",
        "nkap": "Argent",
        "mouv le mouna": "Avorter",
        "niass": "Baiser", "fom": "Baiser", "mbinda": "Baiser",
        "ndamba": "Ballon", "guyo": "Ballon", "guio": "Ballon",
        "nak": "Battre", "basta": "Battre",
        "mô": "Belle", "mo": "Belle", "zouk-miel": "Belle",
        "wat": "Blanc",
        "tongô": "Boire", "jong": "Boisson",
        "yo": "Bonjour", "hao": "Bonjour",
        "motto": "Caca",
        "ngop": "Chaussure", "shouz": "Chaussure", "tchaka": "Chaussure",
        "nkouandjang": "Chien", "dagobert": "Chien",
        "nkunkuma": "Chef",
        "fala": "Chercher",
        "ndji-ndja": "Compliqué", "ntanga": "Compliqué",
        "babana": "Conducteur de moto",
        "shiba": "Descendre", "grap": "Descendre",
        "djoss": "Dire", "tok": "Dire", "toppo": "Dire",
        "chou": "Donner", "tchoko": "Donner",
        "nang": "Dormir",
        "thra": "Draguer", "topor": "Draguer",
        "banga": "Drogue", "gué": "Drogue", "kior": "Drogue", "njap": "Drogue", "lope": "Drogue",
        "ya": "Écouter",
        "bélè": "Enceinte",
        "muna": "Enfant", "mouna": "Enfant",
        "hamboc": "Ennuyer", "hambock": "Ennuyer",
        "pédé": "Efféminé", "ndepso": "Efféminé", "tchèlè": "Efféminé",
        "mbenguiste": "Étranger vivant en occident",
        "mimba": "Être prétentieux",
        "fom": "Faire l'amour", "niass": "Faire l'amour", "kinkonser": "Faire l'amour", "nack mbit": "Faire l'amour", "kombo": "Faire l'amour",
        "mifa": "Famille",
        "lass": "Fesses",
        "ndjoka": "Fête",
        "djoka": "Fête",
        "wé": "Fille", "nga": "Fille",
        "bolè": "Finir",
        "réfré": "Frère", "tara": "Frère",
        "ndambaman": "Footballeur",
        "njoh": "Gratuit",
        "ngomna": "Gouvernement",
        "boum la": "Gronder", "vecto": "Gronder", "brass": "Gronder",
        "ndock": "Gourmand",
        "feyman": "Homme d'affaire malhonnète",
        "hot": "Insulte", "kosh": "Insulte", "cosh": "Insulte",
        "piol": "Maison",
        "tchop": "Manger", "damé": "Manger", "nyama": "Nourriture",
        "waka": "Marcher", "djonny": "Marcher", "dangoua": "Marcher",
        "bahat": "Mauvais coeur",
        "lom": "Mentir",
        "nyè": "Militaire", "mbéré": "Militaire",
        "beta": "Mieux",
        "molla": "Mon ami",
        "chimèn": "Odeur", "noumba": "Odeur (sentir mauvais)",
        "bombo": "Homonyme",
        "abeg": "Pardon", "abeck": "Pardon", "abec": "Pardon",
        "mboa": "Pays Natal",
        "mbeng": "Pays occidental",
        "tara": "Personne",
        "ré": "Position",
        "ngass": "Prison", "ngata": "Prison",
        "maata": "Problème", "blem": "Problème", "mata": "Problème",
        "mbock": "Prostituée",
        "choua": "Prendre", "tcha": "Prendre",
        "clash": "Querelles",
        "kwatt": "Quartier",
        "kwat": "Quartier",
        "bohboh": "Riche", "tehteh": "Riche", "tété": "Riche",
        "fimba": "Ressembler à",
        "briss": "Réussir", "bris": "Réussir",
        "lolo": "Seins",
        "wanda": "S'étonner",
        "comot": "Sortir",
        "réssé": "Soeur",
        "moukouagne": "Sorcellerie", "famla": "Sorcellerie",
        "nian": "Trahir", "niang": "Trahir",
        "wok": "Travail",
        "popoh": "Vrai",
        "fémagnia" : "Escroquerie",
        "femagnia" : "Escroquerie",
        "féman" : "Homme d'Affaire escroc",
        "feymagnia" : "Escroquerie",
        "fémania" : "Escroquerie",
        "femania" : "Escroquerie",
        "feymania" : "Escroquerie",
        "jambo" : "jeu de hasard",
        "djambo" : "jeu de hasard",
        "ndjambo" : "jeu de hasard",
        "njambo" : "jeu de hasard",
        "wandafut" : "étonnant",
        "wandaful" : "étonnant",
        "killam" : "tué",
        "kilam" : "tué",
        "Wandafulkistan" : "Cameroun",
    }

    def remplacer(match):
        mot = match.group(0).lower()
        if mot in correspondances:
            print(f"Correspondance trouvée: {mot} -> {correspondances[mot]}")
        return correspondances.get(mot, match.group(0))

    pattern = re.compile(r'\b(' + '|'.join(re.escape(mot) for mot in correspondances.keys()) + r')\b', re.IGNORECASE)
    texte_traduit = pattern.sub(remplacer, texte)

    return texte_traduit

# Exemple d'utilisation
texte_exemple = "Yo Bro, on va tchop et boire du Tongô après le Wok."
traduction = traduire_argot_en_francais(texte_exemple)
print(traduction)

# %%
hyperlink_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
threshold_ratio = 0.65
relevant_comments = []

# Assuming all_comments is a list of lists, where each inner list has 3 elements
# and the comment text is the third element.

for comment_data in all_comments:
    try:
        comment_text = comment_data[3].lower().strip()
    except IndexError:
        #print(f"Skipping invalid comment data: {comment_data}")
        continue

    emojis = emoji.emoji_count(comment_text)
    text_characters = len(re.sub(r'\s', '', comment_text))

    if (any(char.isalnum() for char in comment_text)) and not hyperlink_pattern.search(comment_text):
        if emojis == 0 or (text_characters / (text_characters + emojis)) > threshold_ratio:
            relevant_comments.append(traduire_argot_en_francais(comment_text)) # Append the entire comment data
print(relevant_comments)

# %%
f = open("ytcomments.txt", 'w', encoding='utf-8')
for idx, comment in enumerate(relevant_comments):
    f.write(str(comment)+"\n")
f.close()
print("Comments stored successfully!")
# Out:
# Comments stored successfully!

# %%
def sentiment_scores(comment, polarity):

  # Creating a SentimentIntensityAnalyzer object.
  sentiment_object = SentimentIntensityAnalyzer()

  sentiment_dict = sentiment_object.polarity_scores(comment)
  polarity.append(sentiment_dict['compound'])
  print(sentiment_dict)

  return polarity


polarity = []
positive_comments = []
negative_comments = []
neutral_comments = []

f = open("ytcomments.txt", 'r', encoding='`utf-8')
print("Reading Comments...")
comments = f.readlines()
f.close()
print("Analysing Comments...")
for index, items in enumerate(comments):
    polarity = sentiment_scores(items, polarity)


    if polarity[-1] > 0.05:
        positive_comments.append(items)
    elif polarity[-1] < -0.05:
        negative_comments.append(items)
    else:
        neutral_comments.append(items)

print(polarity)

# %%
positive_count = len(positive_comments)
negative_count = len(negative_comments)
neutral_count = len(neutral_comments)

# labels and data for Bar chart
labels = ['Positive', 'Negative', 'Neutral']
comment_counts = [positive_count, negative_count, neutral_count]

# Creating bar chart
plt.bar(labels, comment_counts, color=['blue', 'red', 'grey'])

# Adding labels and title to the plot
plt.xlabel('Sentiment')
plt.ylabel('Comment Count')
plt.title('Sentiment Analysis of Comments')

# Displaying the chart
plt.show()
print(positive_count)
print(negative_count)
print(neutral_count)

# %%
# labels and data for Bar chart
labels = ['Positive', 'Negative', 'Neutral']
comment_counts = [positive_count, negative_count, neutral_count]

plt.figure(figsize=(10, 6)) # setting size

# plotting pie chart
#plt.pie(comment_counts, labels=labels)
plt.pie(comment_counts, labels=labels, autopct='%1.1f%%')

# Displaying Pie Chart
plt.show()

# %%
f = open("ytcomments.txt", 'r', encoding='`utf-8')
print("Reading Comments...")
comments = f.readlines()
f.close()
# convert dataset to pandas dataframe
df = pd.DataFrame(comments)
# Out:
# Reading Comments...

# %%
import matplotlib.pyplot as plt
import pandas as pd
from transformers import pipeline

# Load the emotion detection pipeline
classifier = pipeline("text-classification", model="astrosbd/french_emotion_camembert", return_all_scores=True)

# Assuming 'df' is your DataFrame and 'Comment' is the column containing comments
def detect_emotion(text):
    try:
        results = classifier(text)
        # Extract the emotion with the highest score
        return max(results[0], key=lambda x: x['score'])['label']
    except Exception as e:
        print(f"Error processing text: {text}, Error: {e}")
        return "Unknown"  # or handle the error as needed

# Assuming your comments are in a text file named "ytcomments.txt"
f = open("ytcomments.txt", "r", encoding="utf-8")
comments = f.readlines()
f.close()

# Create a DataFrame from the comments
df = pd.DataFrame(comments, columns=["Comment"])

# Apply the emotion detection function
df['emotion'] = df['Comment'].apply(detect_emotion)

# Count the occurrences of each emotion
emotion_counts = df['emotion'].value_counts()


# Create the plot
plt.figure(figsize=(10, 6))
emotion_counts.plot(kind='bar')
plt.title('Emotion Distribution in Comments')
plt.xlabel('Emotion')
plt.ylabel('Number of Comments')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
print(emotion_counts)
# Out:
# emotion
# anger       3760
# neutral     3204
# joy         2495
# sad         2406
# surprise      85
# fear          67
# Unknown       16
# Name: count, dtype: int64

# %%
# prompt: how to determine if a content is in english or in french in ytcomments.txt file data, using a fine tuned model

from transformers import pipeline

# Load the language detection pipeline
classifier = pipeline("text-classification", model="papluca/xlm-roberta-base-language-detection")

def detect_language(text):
    try:
        result = classifier(text)[0]
        return result['label']
    except Exception as e:
        print(f"Error processing text: {text}, Error: {e}")
        return "Unknown"

# Assuming your comments are in a text file named "ytcomments.txt"
f = open("ytcomments.txt", "r", encoding="utf-8")
comments = f.readlines()
f.close()


# Create a DataFrame from the comments (if you haven't already)
import pandas as pd
df = pd.DataFrame(comments, columns=["Comment"])


# Apply the language detection function
df['language'] = df['Comment'].apply(detect_language)

# Count the occurrences of each language
language_counts = df['language'].value_counts()

print(language_counts)

# Further processing or visualization (e.g. plotting)
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
language_counts.plot(kind='bar')
plt.title('Language Distribution in Comments')
plt.xlabel('Language')
plt.ylabel('Number of Comments')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use cpu
# Token indices sequence length is longer than the specified maximum sequence length for this model (606 > 512). Running this sequence through the model will result in indexing errors
# Error processing text: je vous cite le burkinafaso où  le président veille et surveille les directives pour les  réalisations dans tous les domaines de son pays.un président doit être  sur le terrain.. c&#39;est sur le terrain qu&#39;on ressent  la presence d&#39;un président, il choisit d&#39;être  sur le terrain en fonction  de ses humeurs??,c&#39;est quelqu&#39;un qui l&#39;avait forcé de dire oui à la fonctionprésidentielle?? il est administrateur civil de formation ,on dit qu&#39;il était un très bon administrateur . burocrate ,mais est-ce que ça  suffit pour devenir président ? un président c&#39;est quelqu&#39;un  qui a  un esprit de visionnaire qui est rare chez beaucoup  des gens,un président  n&#39;est pas un mystiste ,les gros yeux que fait toujours sortir son ministre du territoire pour menacer les camerounais, c&#39;est maganimagoua qui devait sortir ces gros à  ses fifioribana lorsqu&#39;il ne font pas les choses  comme  il le veut et quand il le veut ! un président doit penser chaque jour qu&#39;il doit rendre compte aux contribuables qui lui paye un salaire , mr en costume, sincèrement  ne veut pas dire la vérité, il parle d&#39;agenda caché pour noyer la magistrale intervention de son contradicteur.. vraiment  le pays va très  mal,un président n&#39;est pas un roi,,c&#39;est un ouvrierr du peuple, il est obligé  d&#39;etre partout s&#39;il le faut, raison pour laquelle  le peuple qui est son employeur  lui donne  toutes les clés ,le  matériel,sa sécurité et autres pour pouvoir mieux surveiller les chantiers et autres sur le terrain, sachez le .  . monsieur  en costume,je suis scandaleusement outré de constater à  quel point le grand  sorcier maganimagoua  a rendu mystique  ou mystérieuse la fonction  de président de la république vraiment, la conservation abusive de la fonction présidentielle est destructrice d&#39;un pays ,c&#39;est le cas actuellement  au pays du grand sorcier  maganimagoua,voilà  la source de tous les malheurs que subissent les camerounais  au quotidien depuis  1992 (election présidentielle muselement  du sdf et de mr john  frudi),ce qui me fait encore plus mal,c&#39;est que le grand sorcier maganimagoua  envoie tout le monde à  la retraite, mais maganimagoua à  son tour  refuse de prendre sa retraite, c&#39;est  très  bizarre!! on marche sur la tête!! c&#39;est de la pure sorcellerie !! maganimagoua est dans l&#39;appareil  gouvernementale du cameroun depuis 1962 jusqu&#39;à maintenant. royaume ou république.. dites moi!!
# , Error: The expanded size of the tensor (606) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 606].  Tensor sizes: [1, 514]
# Error processing text: pour une foie je trouve marlize douala bell intéressante dans un débat. elle accepte aujourd&#39;hui que nos frères sawa doivent se battre aussi come tout les autre pour avoire une place au soleil au lieu de pleurnicher. l&#39;impression que nous a toujours donné c&#39;est que le bamiléké prennent toute les terres, sans toutefoie dire que l&#39;acquisition d&#39;une terre est un échange de valeure foncier contre une valeure monétaire qui est aussi échangeable a autre chose. si bafoussam est envahi, c;est la preuve que les terres se vendent aussi a l&#39;ouest et le meme phénomènes qui se passe a douala et a yaoundé est present a bafoussam par example. ne serait-ce que pour des raisons de développement, les grandes ville a un moment constituent de métropoles et font l&#39;objet d&#39;exode rurale. pour permettre les de-congestions populaires, le nigeria a ete oblige de deplaced sa capitale a abuja et cela a fait tres grand bien. notez aussi que on ne peut pas limiter le progrès de development d&#39;un etats pour  freiner une tribu. le capitalisme est un phénomène qui n&#39;a pas de limite. je ne finirais pas sans dire bravo a la maman commerçant qui a dit des choses fundamentale vrais dans ses propos. quant il s&#39;agit du progrès, du development, ou meme combattre un fléau qui mine un peuple, il s&#39;agit tout simplement de regarder, d&#39;observer et d&#39;imiter ou meme copier l&#39;autre dans ce qu&#39;il fait bien. etre capable de se surpasser de ses complexes de n&#39;importe quel genre et de se mettre au travail. lorsqu&#39;on le fait il y a toujours un résultat et ce résultat, positif ou négatif permet de tirer des lessons, faire un conclusion et continuer en se mettant encore au travail parce que c&#39;est la seule chose qui libère. le peuple chinois nou parle de façon très explicite. il y a 45 an ce peuple mourrait de famine. aujourd&#39;hui il vendent la nourriture au reste du mon inclut les etats-unis. le peuple sud-coréen dans les année 1981, 1982 recevait l&#39;aide du cameroon parmis tant d&#39;autre. aujourd&#39;hui, si ton écran n&#39;est pas samsung, tu n&#39;en a pas encore une. tout ca pour simplement dire que le développement est d&#39;abord autocentrer dans la resolution dun problem personnel, communautaire ou nationale avant de devenir mondial. come disait besala sur autre plateau, les bamilékés ont été victim du tribalisme au temps colonial ce qui a développé en eu un replis et une auto determination de subvenir au difficultes dont ils fesait face. ducoup les parent et les enfants trouvaient le travail come le seul moyen de liberation que ce soit dans les champs, les plantation ou meme les fermes domestiques. mais avant de terminer, je dirais que moi aussi j&#39;aurais pris l&#39;avocate pour une sawa si elle ne se presente pas. la maman commerçante a dit une autre  vérité qui est que, les filles et meme les gars bamiléké ne connaissaient pas se mettre surtout dans les années 80 et meme debut 90. du coup les filles sawa était les model de fille avec qui les gars voulaient sortir. de ce fait les brassages et meme mariages inter ethnic et meme intertribales naissaient avec le temps. mais il faut dire que la période ou les replis communautaires ont commencé a disparaître au moment du maquis (lute nationaliste) parce que ca avait permis les mouvement sous-terrains des uns et des autres qui se retrouve dans les forêt du mungo et de la sanaga maritime, favorisant ainsi le brassage de marriages. bravo au femmes camerounaises!!!
# , Error: The expanded size of the tensor (857) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 857].  Tensor sizes: [1, 514]
# Error processing text: assassinat de zogo martinez - la piste macron-biya <br>macron le maître du lieu-dit cameroun serait peut-être, avec biya, le commanditaire de l&#39;assassinat de zogo martinez.<br><br>1 - menacé par la rébellion en centrafrique pilotée par macron, biya aurait accompagné touadéra faustin archange allié de la russie ennemie de macron.<br><br>2 - on sait qu&#39;amougou belinga, l&#39;emblématique homme d&#39;affaires de biya, est le parrain de la télévision d&#39;état, l&#39;unique chaîne de télévision de centrafrique.<br><br>3 - biya paul aurait ainsi commis le crime de lèse-majesté envers macron.<br><br>4 - macron aurait donc décidé de marchander à biya la présidentielle de 2025. macron pourrait en effet soutenir par exemple un &quot; président élu &quot; auto-proclamé comme kamto maurice en 2018<br><br>5 - biya se serait engagé à lâcher amougou belinga pour pouvoir se maintenir en 2025. macron et biya auraient alors recruté l&#39;animateur radio à gages camerounais zogo martinez pour démolir l&#39;image d&#39;amougou belinga. une fois sa part de marché accomplie, zogo martinez aurait été assassiné pour incriminer amougou belinga et cacher la piste macron-biya.<br><br>6 - sans l&#39;adhésion populaire à la forte indignation contre lui des chefs traditionnels de la lékié terroir de la victime, biya n&#39;aurait peut-être pas bougé son petit doigt.<br><br>7 - la réaction de biya ne serait donc qu&#39;une mascarade judiciaire pour calmer la population et rassurer macron.<br><br>8 - biya aurait ainsi sournoisement configuré son système judiciaire pour accabler amougou belinga et faciliter son lâchage officiel <br><br>9 - la barbouzerie médiatique française, ses relais et réseaux sociaux camerounais, auraient reçu la mission de maquiller l&#39;assassinat de zogo martinez en affaire amougou belinga pour cacher la piste macron-biya.<br><br>10 - ainsi, la piste de l&#39;assassinat de zogo martinez pourrait remonter jusqu&#39;à macron. d&#39;où le flou, les insuffisances, les tripotages, bref les atermoiements d&#39;une justice corrompue, noyautée par une opposition réserviste de l&#39;élysée.
# , Error: The expanded size of the tensor (601) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 601].  Tensor sizes: [1, 514]
# Error processing text: salutations en yeshua !<br>d&#39;où vient-il qu&#39;un bandit soit alors devenu ministre ?<br><br><br><br>psaume 94<br><br><br>«1 dieu des vengeances, éternel! dieu des vengeances, parais! 2 lève-toi, juge de la terre! rends aux superbes selon leurs oeuvres! 3 jusques à quand les méchants, ô éternel! jusques à quand les méchants triompheront-ils? 4 ils discourent, ils parlent avec arrogance; tous ceux qui font le mal se salutations en yeshua christian !<br>je prie que yahweh yeshua le seul créateur de tout l&#39;univers, de toutes les choses et de tous les êtres soit le seul maître de ta vie.<br><br>c&#39;est lui qui t&#39;a créé.<br>personne ne peut t&#39;aimer mieux que ton créateur !<br>invite ton créateur à toujours marcher devant toi pour te guider, pour veiller sur toi !<br>il est vivant, juste et fidèle.<br><br>merci ô yahweh yeshua, infiniment !. 5 éternel! ils écrasent ton peuple, ils oppriment ton héritage; 6 ils égorgent la veuve et l&#39;étranger, ils assassinent les orphelins. 7 et ils disent: l&#39;éternel ne regarde pas, le dieu de jacob ne fait pas attention! 8 prenez-y garde, hommes stupides! insensés, quand serez-vous sages? 9 celui qui a planté l&#39;oreille n&#39;entendrait-il pas? celui qui a formé l&#39;oeil ne verrait-il pas? 10 celui qui châtie les nations ne punirait-il point, lui qui donne à l&#39;homme l&#39;intelligence? 11 l&#39;éternel connaît les pensées de l&#39;homme, il sait qu&#39;elles sont vaines. 12 heureux l&#39;homme que tu châties, ô éternel! et que tu instruis par ta loi, 13 pour le calmer aux jours du malheur, jusqu&#39;à ce que la fosse soit creusée pour le méchant! 14 car l&#39;éternel ne délaisse pas son peuple, il n&#39;abandonne pas son héritage; 15 car le jugement sera conforme à la justice, et tous ceux dont le coeur est droit l&#39;approuveront. 16 qui se lèvera pour moi contre les méchants? qui me soutiendra contre ceux qui font le mal? 17 si l&#39;éternel n&#39;était pas mon secours, mon âme serait bien vite dans la demeure du silence. 18 quand je dis: mon pied chancelle! ta bonté, ô éternel! me sert d&#39;appui. 19 quand les pensées s&#39;agitent en foule au dedans de moi, tes consolations réjouissent mon âme. 20 les méchants te feraient-ils siéger sur leur trône, eux qui forment des desseins iniques en dépit de la loi? 21 ils se rassemblent contre la vie du juste, et ils condamnent le sang innocent. 22 mais l&#39;éternel est ma retraite, mon dieu est le rocher de mon refuge. 23 il fera retomber sur eux leur iniquité, il les anéantira par leur méchanceté; l&#39;éternel, notre dieu, les anéantira. <br><br>et toute la création dit :<br>«oui et amen !»<br><br>ô yahweh yeshua, sauve le cameroun et les camerounais.<br>yahweh yeshua est vivant, juste et fidèle.<br>merci ô yahweh yeshua, infiniment !
# , Error: The expanded size of the tensor (849) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 849].  Tensor sizes: [1, 514]
# Error processing text: <a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a><a href="uckszu2wh9gy1mb0dv-11ujg/b8ify7zok9ivknap_i2a-ay"></a> plus jamais plus jamains
# , Error: The expanded size of the tensor (672) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 672].  Tensor sizes: [1, 514]
# Error processing text: grand frère, tu as des preuves des paiements dont tu parles? quand tu dis qu&#39;un homme est payé tu peux le prouver ? si je diffuse sur le net que valsero est g-a-y, penses tu que cela est responsable.<br>si toi tu es soldat du cameroun, nous en sommes contents, mais pourquoi tu estimes que personne ne peut vouloir l&#39;être pour le continent.<br>donc tu serais celui là qui donne des bons et mauvais points aux actions souverains des uns et des autres. comme quoi tu as fait la prison et ce que lui peut endurer n&#39;a pas de considération ?<br>je vous suis tous 2 comme beaucoup de camerounais, et je peux objectivement te dire à quoi ça ressemble de loin : &quot;si on est pas d&#39;accord avec votre vision des choses, tu te mets a calomnier, et plus tard tu vas jeter en prison.&quot;<br>si tu n&#39;es pas d&#39;accord avec lui,soit tu lui donnes tes contre-arguments ou laisse parler tout seul. d&#39;où vient il que tu le traite d&#39;avoir un agenda caché (tu l&#39;as fait dans une de tes vidéos). <br>ensuite je ne suis pas d&#39;accord avec cette façon de faire que nous avons de couper les propos des uns et des autres et les sortir de leur contexte. <br>pour le fond, ses conférences ont déjà donner des éléments sur la procédure qu&#39;il propose et même toi tu ne répondras à cette question que tu lui demandes par sarcasme.<br>sur la question d&#39;assimi goïta, nous avons suivis cette histoire avec discipline, et en aucun moment franklin nyamsi n&#39;est en contradiction avec ses valeurs. c&#39;est justement pour ça qu&#39;il a le respect du gouvernement de la transition malienne. pire encore, tes propos sous-entendent que ce gouvernement est débile. pourquoi ne te demandes tu pas pourquoi il bénéficie de leur respect. s&#39;il te plaît arrête les conclusions hâtives, ça ne d&#39;honorer pas cher grand frère.<br>quand tu ne maîtrises pas un sujet,renseignes toi au lieu de raconter des mensonges qui induisent en erreur ceux qui t&#39;écoute avec assiduité. il est est de même pour l&#39;ensemble de ses prises de position au tchad, au burkina, en côte d&#39;ivoire.<br>enfin, laisses moi te dire que tu n&#39;écoutes pas très souvent tes propres vidéos, sinon tu n&#39;aurais pas ouvert ce genre de débats (oui faut le dire c&#39;est toi qui a commencé tout ça). dans plusieurs de tes propres vidéos, tu touches du doigt l&#39;incapacité des camerounais à se mobiliser quand celà est nécessaire. on a encore des épisodes de l&#39;enfermement du prof mk chez lui, de l&#39;enfermement arbitraire de bibou nissack et d&#39;alain fogué, de l&#39;arrestation de sébastien ebala, et d&#39;autres encore sans que ça m&#39;émeut des camerounais. tu sais tout ça. tu sais que le dernier scrutin n&#39;a pas produit cette mobilisation, et dans ta tête ça se fera sûrement en 2025.<br>grand frère si franklin nyamsi rêve, tu es tout autant dans le déni.<br>la seule différence qui vous sépare, c&#39;est qu&#39;il demande de préparer le peuple maintenant.<br>et si réellement tu voulais qu&#39;il te donne des éléments, tu te serais rapproché de lui.<br>moi qui te suis tous les jours, je suppose que cette fois, moi aussi tu vas me considérer comme un vendu?. ça me plairait de savoir ce que tu diras.<br>de toute façon, même si tu me bloques je continuerai de te suivre par d&#39;autres canaux.
# , Error: The expanded size of the tensor (870) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 870].  Tensor sizes: [1, 514]
# Error processing text: valsero tu dis que le prof nyamsi ne fait pas la lutte politique comme toi .alors je voudrais savoir ce que tu appelles lutte politique. qu&#39;est ce que tu as fait et que tu fais de different par rapport a mr nyamsi  dans la lutte pour le changement  au cameroun pour croire que toi tu es dans la lutte institutionnelle et lui franklyn non ? tu prends une partie de la reponse de franklyn nyamsi pour le presenter comme un hors sujet .cest de la manipulation  que tu fais alors que mr le combattant politique critique la manipulation de paul biya .tu es incoherent frerot ! et je pense que tu as une vue superficielle de l&#39;  attitude  politique  de mr nyamsi avec kaka deby , assimi goita . mr nyamsi etait en desaccord avec assimi goita ,  avec kaka au moment où ces derniers faisaient bras dans bras avec la france afrique. ce systeme que mr nyamsi combat farouchement. alors dès que ces derniers ont tourné le dos a la france afrique mr nyamsi s&#39;est engage a les defendre .. ce nest pas mr nyamsi qui a change de veste .ce sont plutot ces chefs d&#39;etat qui ont rejoint mr nyamsi dans son combat pour la souveraineté vrai. voici la verite.  quand aux choix politique de participer aux elections au cameroun mr nyamsi dit tout simplement que ça ne sert a rien d&#39;aller aux elections où le vainqueur est deja connu . ce qu&#39;il Écouter a faire cest d&#39;activer le lion indomptable dans l&#39;esprit d&#39;une  masse critique de la population pour degager biya. il faut commnuniquer ! communiquer et continuer a communiquer pour reveiller le lion indomptable dans l&#39;esprit du peuple. voici la position du prof.  ceci doit meriter  des injures ? tu critiques le choix politique de biya et tu insultes celui qui  critique le  choix politique de ton leader qui aspire a gouverner.cest de l&#39;incoherence. ce sont les signes  de la dictature alors que vous affirmez combattre la dictature . je pense que tu veux te servir d&#39;un Querelles avec le prof pour accroitre ton aura. voici pourquoi tu t&#39;agites
# , Error: The expanded size of the tensor (520) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 520].  Tensor sizes: [1, 514]
# Error processing text: valsero ne concoit pas l&#39;idee qu&#39;un africain puisse reagir sur les actualités de son continent de maniere transversale. sinon il traiterait pas les panafricanistes de mercenaire. <br><br>quand tu dis qu&#39;il est payé valsero, as tu son code bancaire ou tu as vu les transferts de bia, ou de kaka deby ? ou meme de goita ? ou de poutine.<br><br>crois tu que la france qui scrutte ce genre de transfert depuis des années n&#39;aurait pas directement saisi la justice francaise ?<br><br>ce que je comprend de ta reaction valsero, c&#39;est juste de la jalousie, tu es minable. tu as vu en 2025 comment les africains aiment le professeurs , ils l&#39;ont aidé meme finacierement pendant les periodes difficules, il est acceuilli en grande pompe dans les pays qui défend la fiérté africaine. <br>et ca te fait mal, ca te fait mal de voir quelqu&#39;un qui donne tout pour l&#39;afrique être autant aimé, et atteindre un niveau que tu sais que tu n&#39;atteindra jamais. c&#39;est ça la jalousie, tu n&#39;as pas confiance a ce que dieu t&#39;a donné et regarde dans l&#39;assiete de ton frere et grince des dents. car soyons honnete ce n&#39;est pas ses idées sur le cameroun et sur l&#39;afrique qui te dérange car en soit tu partage les idées similaire, je t&#39;ai vu a plusieurs reprises félicité les actions politique de nos dirigeants au sahel.  mais ce qui te dérange c&#39;est le succes du professeur, car tu aurais aimé faire pareil. tu te dis comment les africains peuvent lui donner 30 000 euro en a peine quelques semaine alors que toi tu travaille pendant 1 ans pour ça 😂 ! cette générosité des africains et la preuve que le professeur fait un travail de qualité pour l&#39;afrique.<br><br>je comprend ta surprise mon frere, car toi tu ne crois pas en l&#39;homme noir, tu ne crois à l&#39;afrique , je sais que tu ne crois meme pas en toi meme !  tu n&#39;as pas confiance a tes freres freros alors quel visions as tu pour l&#39;afrique et ton peuple ? rien mon frere... walou , nada.<br><br> mais toi tu crois etre le gardien de ton frere ? cette expression vient du livre de genese dans la bible mais tu n&#39;es pas celui que tu crois etre valsero ! <br><br>je crois que tu t&#39;es trompé. car effectivement tu es bien un caïn qui a tué son frere par jalousie ! <br><br>et oui mon frere caïn valsero ! <br>c&#39;est tonton et bienvenue dans ma clinique. <br><br>&quot;suis je le gardien de mon frere ?? &quot;<br><br>c&#39;etait ça ta reponse apres que dieu t&#39;aie demandé ou se trouvais celui que tu as assassiné par  jalousie ! <br><br>je le laiserais pas le professeur etre ton abel frero, c&#39;est fini ces temps là !! <br><br>si tu as mal, il faut laisser ta clinique et aller te procurer quelque pain spirituel de la liberté. et te mettre a l&#39;école de la maat.<br><br>tous les aigri de bia, de ouatara et meme de bassirou se rassemble sous ta video pour te feliciter. <br><br>arretez de faire pitié...<br><br><br>ton seul argument c&#39;est l&#39;intellectuel à gage qui se base que sur rien de veridique si ce n&#39;est ta faible compréhension des choses donc ton ignorance.<br><br>si défendre l&#39;identité africaine continental et sa souverainté fait de moi un intellectuel à gage, alors je suis fier d&#39;en etre un.<br><br>on nous insulte deja de tous les noms, par les europeens et meme par mes freres perdu d&#39;afrique. ta critique est peu de choses face a l&#39;immensité du combat a mener.<br>tu veux juste attirer la sympathie de kamto, mais mon frere arrete.. <br><br>tu es le genre de personne qui pense que pour evoluer, il faut forcement s&#39;attaquer a son frere. tu penses que tu ne peux pas grandir par toi meme mais frero la tribune de l&#39;afrique est vaste, il y a de la place piur tous ceux qui veulent vivre et mourir pour l&#39;afrique ! alors vas y et soit en paix. <br><br>donc merci frero, on est ensemble, on va aussi prendre soin de toi, la ou tu vas nous aussi on y va.<br><br>et maintenant bouge de ma cl ...
# , Error: The expanded size of the tensor (1119) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1119].  Tensor sizes: [1, 514]
# Error processing text: chapitre 1<br><b>franklin nyamsi : un agent double au service de ses propres intérêts</b><br>franklin nyamsi se présente comme une figure publique,se déclarant « professeur » sans qu’aucun cadre formel ne vienne appuyer ce titre autoproclamé, franklin nyamsi illustre cette capacité de certains talents oratoires à confondre forme et fond, tout en exploitant les failles des esprits crédules.<br>franklin nyamsi incarne aujourd’hui une figure controversée dont les actions et affiliations suscitent des doutes profonds quant à ses véritables convictions, il se décrit comme un panafricaniste déterminé, mais son parcours trahit des prises de position contraires à l’esprit du panafricanisme. entre 2005 et 2010, il était coté de blaise compaoré le meurtrier de thomas sankara, ce héros visionnaire africain qui symbolise la lutte pour la souveraineté. cette posture, couplée à ses liens douteux avec blaise compaoré, complice notoire dans l’assassinat de sankara, jette une ombre sur sa crédibilité. peut-on sincèrement croire en la sincérité de son engagement panafricaniste?<br> nyamsi n’a pas hésité il y a moins de 10 ans à défendre le franc cfa auprès de ouattara et soro, ce vestige colonial honni par les panafricanistes authentiques. cet historique dévoile une incohérence flagrante entre ses discours et ses convictions profondes. peut-on réellement espérer l’émergence d’une afrique émancipée lorsqu’un de ses défenseurs autoproclamés s’est solidement enraciné dans un système qu’il prétend désormais dénoncer ?<br>la figure politique autour de laquelle gravite franklin nyamsi n’est autre que guillaume soro, un ancien chef rebelle devenu symbole de l’opportunisme politique. soro est perçu par la grande majorité des ivoiriens comme un traître ayant utilisé la violence et des alliances francaises pour servir ses ambitions personnelles. nyamsi, conseiller attitré de cet homme décrié, partage ainsi une complicité qui questionne profondément sa loyauté envers la cause panafricaine. son alibi – jadis la discrimination des nordistes – ne tient plus. dans une élection libre en côte d&#39;ivoire, ouattara battrait soro même à l&#39;age de 100 ans, non pas en raison de sa force politique, mais parce que soro est perçu comme un traître et un anti-panafricain.<br>l&#39;image la plus humiliante pour l&#39;africain après l&#39;esclavage et la colonisation est celle d&#39;un président et de sa famille délogés du pouvoir à moitié nus par l&#39;armée française, une stratégie initialement conseillée par une équipe dont  franklin nyansi en faisait partie.<br>peut-on faire confiance à celui qui s’engage aux côtés d’un homme dont le parcours est marqué par des actes de déstabilisation et des partenariats douteux avec des puissances étrangères ? loin de représenter des idéaux panafricanistes, cette alliance renforce les suspicions sur les véritables motivations de franklin nyamsi.<br>ce qui est particulièrement troublant, c&#39;est la manière dont franklin nyamsi se complaît dans une intellectualité dépassée. il s&#39;adonne à un archivage lugubre et désagréable de livres en grande partie en français, pensant que cela témoigne d&#39;un niveau littéraire élevé. à une époque où l&#39;on peut compacter des milliers de livres dans un simple téléphone, son obsession pour la matérialité du livre révèle une stratégie maladroite pour manipuler les esprits naïfs.<br>son obsession pour des symboles dépassés renforce cette image d’un individu manipulant habilement les esprits les moins avertis. franklin nyamsi semble davantage préoccupé par l’impact que produisent ses discours que par des solutions concrètes à proposer pour libérer le continent des carcans néocoloniaux.<br>franklin nyamsi bénéficie aujourd’hui des avantages d’un système français qu’il critique pourtant ouvertement. vivant confortablement en france, il profite des largesses d’un état profondément impliqué dans le pillage économique de l’afrique. ce paradoxe fragilise encore plus son dis ...
# , Error: The expanded size of the tensor (1608) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1608].  Tensor sizes: [1, 514]
# Error processing text: psaume 94<br><br><br>«1 dieu des vengeances, éternel! dieu des vengeances, parais! 2 lève-toi, juge de la terre! rends aux superbes selon leurs oeuvres! 3 jusques à quand les méchants, ô éternel! jusques à quand les méchants triompheront-ils? 4 ils discourent, ils parlent avec arrogance; tous ceux qui font le mal se glorifient. 5 éternel! ils écrasent ton peuple, ils oppriment ton héritage; 6 ils égorgent la veuve et l&#39;étranger, ils assassinent les orphelins. 7 et ils disent: l&#39;éternel ne regarde pas, le dieu de jacob ne fait pas attention! 8 prenez-y garde, hommes stupides! insensés, quand serez-vous sages? 9 celui qui a planté l&#39;oreille n&#39;entendrait-il pas? celui qui a formé l&#39;oeil ne verrait-il pas? 10 celui qui châtie les nations ne punirait-il point, lui qui donne à l&#39;homme l&#39;intelligence? 11 l&#39;éternel connaît les pensées de l&#39;homme, il sait qu&#39;elles sont vaines. 12 heureux l&#39;homme que tu châties, ô éternel! et que tu instruis par ta loi, 13 pour le calmer aux jours du malheur, jusqu&#39;à ce que la fosse soit creusée pour le méchant! 14 car l&#39;éternel ne délaisse pas son peuple, il n&#39;abandonne pas son héritage; 15 car le jugement sera conforme à la justice, et tous ceux dont le coeur est droit l&#39;approuveront. 16 qui se lèvera pour moi contre les méchants? qui me soutiendra contre ceux qui font le mal? 17 si l&#39;éternel n&#39;était pas mon secours, mon âme serait bien vite dans la demeure du silence. 18 quand je dis: mon pied chancelle! ta bonté, ô éternel! me sert d&#39;appui. 19 quand les pensées s&#39;agitent en foule au dedans de moi, tes consolations réjouissent mon âme. 20 les méchants te feraient-ils siéger sur leur trône, eux qui forment des desseins iniques en dépit de la loi? 21 ils se rassemblent contre la vie du juste, et ils condamnent le sang innocent. 22 mais l&#39;éternel est ma retraite, mon dieu est le rocher de mon refuge. 23 il fera retomber sur eux leur iniquité, il les anéantira par leur méchanceté; l&#39;éternel, notre dieu, les anéantira. <br><br>et toute la création dit :<br>«oui et amen !»
# , Error: The expanded size of the tensor (638) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 638].  Tensor sizes: [1, 514]
# Error processing text: quelle deception!!<br>deux combatants de la liberté, tous exilés du régime biya, tous ennemis du régime se déchirent bêtement tout simplement parceque ils n&#39;ont pas la même façon de voir les choses, la même méthode d&#39;agir pour libérer le cameroun. je ne parle même pas de l&#39; orgueil dans l&#39;air. et nous le peuple, que devons nous penser ou retenir de votre combat de coq égoïste ? ou est l&#39; intelligence, ou est l&#39; amour tant crié ici dans vos dernières prises de paroles ? vous vous blessez avec des mots, vous vous jalousez, pire vous ne vous écoutez même plus depuis longtemps, vous vous entendez seulement. et plus vous vous entendez plus vous développez la haine. et vu que vous n&#39; avez aucun compte à nous rendre, nous le peuple meurtris, alors votre combat n&#39; a rien avoir avec nous le peuple. pourquoi ne pas déposer les armes, essuyez les larmes de vos yeux pour constater qu&#39;en faite vous êtes du même côté de l&#39;histoire, du même côté du monde en exile. pourquoi tant d&#39;ingéniosité pour fabriquer des phrases, agencer les mots pour vous blesser inutilement, c&#39;est contra productif pour la lutte et pour l&#39;union de toutes les forces pour le changement. essuyer ces salives immondes qui vous ombragent pour vous rendre compte que vous avez le même adversaire biya paul, taisez-vous et calmez vous pour mieux discerner le fond de vos paroles, alors seulement peut être vous pourriez vous rendre compte que c&#39;est uniquement l&#39; amour pour le cameroun qui avait rapproché dans le passé, qui vous a fait vous connaître. pourquoi vous faire la guerre alors que bien que vos armes sont différentes votre adversaire lui est le même. même vos doutes l&#39;un contre l&#39;autre ne sont que le produit de la colère et de la haine. est ce que c&#39;est pas mieux de combiner vos actions ? n&#39;est ce pas en 2018 que vous aviez essayé cette même méthode que vous voulez réchauffer pour 2025 ? et pourquoi ne remarquez vous pas que cette fois ci les camerounais même sans les politiques sont plus décidés à descendre dans les rues pour crier leur ras le bol et on constate qu&#39;ils ont déjà commencé à le faire au nord du pays, au sud et ça se répand lentement mais sûrement. <br>vous êtes des papas avec un feu 🔥pour le cameroun qui brûle dans vos cœurs et c&#39;est évident. vos avez plus de choses qui vous unies que qui vous divises très cher fils de um nyobe.<br>respectez vos douleurs et n&#39;en rajoutez pas l&#39; un à l&#39;autre. c&#39;est totalement inutile et improductif.  en plus vous nous faites davantage souffrir et vous nous faites penser que biya et son régime ont le pouvoir de vous diviser à jamais. je refuse de le croire. je suis convaincu que vos coups ensembles vers votre adversaire ont déjà commencé à l&#39;affaiblir au point où ils essaient aujourd&#39;hui de vous diviser pour continuer à régner. ressaisissez vous donc très vite ! respectez vous, vos âges, et votre long chemin dans la lutte et unissez vous pour le dernier kilomètre. ce n&#39;est plus loin, on y est presque. si l&#39;un de vous pouvait lire mon message, je prie qu&#39;il soit le premier à s&#39;humilier et à faire le premier pas du pardon vers l&#39;autre en prenant appuie sur le cameroun. nous vous aimons vous deux.<br>danydan😪 😥
# , Error: The expanded size of the tensor (829) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 829].  Tensor sizes: [1, 514]
# Error processing text: sôtises mon géneral!!!..  je ne dis pas que tu as tords,  mais tu n&#39;as pas raison dans ce coup là....on  a  tous suivis les propos du prof. contre cabral libii et mk, ..... malheureusément tu n&#39;avais pas été à la hauteur pour comprendre qu&#39;il faisait les éloges à mk et non le contraire. sauf s&#39;il n&#39;Écouter que toi qui doit jouer ce rôle, dis nous. que-ce que tu lui réproche au juste?...le fait de dire qu&#39;on ne pourra pas chasser biya du pourvoir par les urnes???...mais est-ce célà t&#39;empèche de continuer  à la sensibilisations des masses, ?? non!!!...si tu es convaincu de ce que tu fais pourquoi ne pas l&#39;ignoré tout simplément???..il t&#39;empêche de faire quoi au juste?...je suis désolé  tu es l&#39;agresseur dans cette histoire pas le prof. nous suivons tous vos publications,  tu te crois le directeur des conciensces des gens et tu décide qui doit publier quoi ou non. je suis désolé cher general tu l&#39;a bien chercher et tu as trouvé!....tu as beaucoup fait dans ce combat , hélas tu n&#39;es pas omniscient,  tu peux aussi te trompé dans tes analyses comme le prof aussi,  mais ta sorti d&#39;aujourd&#39;hui est bien médiocre car c&#39;est aller dans tous les sens sauf là où il faut. pardon mon géneral il faut rétenir céci : il savoir choisir ses luttes et bien connaître son adversssaire avant de s&#39;engagé. le spectacle que tu donnes à l&#39;heure n&#39;honnor personne. tu es une star 🌟 ne l&#39;oublies pas et la vie va continuer après octobre. si tu estimes que tu dois répondre aux attacques du grands prof vas_y mais il faut lui opposer des arguments intéllectuel pas le kongossa dans un vocabulaires  de caniveau , réserve ça pour nous autres. enfin, tu es entrain de faire des actions contre productive pour le mrc . tu es un cadre alors tu dois toujours mésurer la porté des tes actes.  pardon , pour tous ceux qui lisent et répondent au commentaire . il faut corriger mon français tout doucément car je vous connais. 😂😅😂😂 . j&#39;ai donné mon avis personel et célà m&#39;engage !!!!😂😂😂😂
# , Error: The expanded size of the tensor (543) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 543].  Tensor sizes: [1, 514]
# Error processing text: @ valsero:<br> <br> il ne suffit pas de sucer les vues des internautes incrédules en insultant le dr franlkin nyamsi wa kameroun pour convaincre: tu es vraiment décevant en te livrant à la calomnie gratuite et destructive sans y apporter de la valeur ajoutée pour le combat que le continent (afrique) tout entier mène en se moment même pour se libérer des griffes acérées des fauves qui continuent de le piller. <br>dans ce registre, ce que tu appelles&quot; les petits militaires&quot; , quel toupet!  , eux au moins ( bourkina faso, mali et niger) nous démontrent par des faits: transformation positive de la vie de leurs populations, innovations technologiques (production de voitures électriques, mise en place d&#39;usines de transformation des produits de première nécessité, projet de construction d&#39;une centrale nucléaire), prise conséquence des parts de marché en créant une compagnie aérienne fiable et rentable (ceux qui encore de la mémoire, se souviennent bien de ce qu&#39;est devenue air afrique non?! enfin  juste pour rappel...au cas où...) <br><br>lutte contre les terro--ris---tes avec des résultats observables, et j&#39;en passe...<br><br>et franklin nyamsi dans tout ça? <br><br>eh ben, il mène à sa manière et avec les armes intellectuelles dont il dispose le même combat dans lequel il prend les coups de tous les jours et de tous côtés (même des siens!)  pour libérer la parole! <br>pour rappel, même s&#39;il donne l&#39;impression de faire volte face, il faut reconnaitre que c&#39;est suite aux changements bénéfiques aux populations opérés par certains régimes politiques dont il était autrefois très critique qu&#39;il se positionne et ajuste ses analyses &quot;acerbes&quot;, car comme dit le dicton populaire, seuls les imbéciles ne changent pas d&#39;avis! et vu que le dr franklin nyamsi est loin d&#39;être un imbécile, alors bien sûr il ajuste sa pensee critique au gré des évolutions et c&#39;est normal!<br><br>son combat est salutaire et contribue à l&#39;eiveil des masses endormies, je pense sans me tromper que tu en fait partie (vue ta réaction surprenante à mon goût). <br>je ne pense pas que le dr nyamsi  fait cela pour des raisons pécuniaires, si non il aurait pris un raccourci pour arriver plus vite à son but !!! <br><br>alors faire du buzz sur youtube (comme tu le fais ici)  et semer la zizanie contribuent à nous diviser, nous distraire, nous détourner des vrais objectifs, et donc de nous fragiliser davantage face à ceux qui veulent continuer de sucer le continent.<br><br>si je peux me permettre de te poser une question,  qu&#39;as-tu apporté comme valeur ajoutée réelle pour le combat de lutte pour l&#39;emancipation du peuple africain depuis que tu publies des vidéos sur youtube ? <br><br>alors ... dorénavant, tu dois eviter la polémique inutile et te concentrer sur des sujets qui vont contribuer à eveiller la jeunesse africaine afin de  produire la masse critique nécessaire pour liberer le continent des griffes des pilleurs...<br><br>en espérant que tu recevras cette critique de manière constructive avec positivisme et sans condescendance...<br><br>notre linge sale doit être lavé en famille et non sur la place publique!<br><br>merci de ta compréhension affectueusement...
# , Error: The expanded size of the tensor (855) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 855].  Tensor sizes: [1, 514]
# Error processing text: psaume 94<br><br><br>«1 dieu des vengeances, éternel! dieu des vengeances, parais! 2 lève-toi, juge de la terre! rends aux superbes selon leurs oeuvres! 3 jusques à quand les méchants, ô éternel! jusques à quand les méchants triompheront-ils? 4 ils discourent, ils parlent avec arrogance; tous ceux qui font le mal se glorifient. 5 éternel! ils écrasent ton peuple, ils oppriment ton héritage; 6 ils égorgent la veuve et l&#39;étranger, ils assassinent les orphelins. 7 et ils disent: l&#39;éternel ne regarde pas, le dieu de jacob ne fait pas attention! 8 prenez-y garde, hommes stupides! insensés, quand serez-vous sages? 9 celui qui a planté l&#39;oreille n&#39;entendrait-il pas? celui qui a formé l&#39;oeil ne verrait-il pas? 10 celui qui châtie les nations ne punirait-il point, lui qui donne à l&#39;homme l&#39;intelligence? 11 l&#39;éternel connaît les pensées de l&#39;homme, il sait qu&#39;elles sont vaines. 12 heureux l&#39;homme que tu châties, ô éternel! et que tu instruis par ta loi, 13 pour le calmer aux jours du malheur, jusqu&#39;à ce que la fosse soit creusée pour le méchant! 14 car l&#39;éternel ne délaisse pas son peuple, il n&#39;abandonne pas son héritage; 15 car le jugement sera conforme à la justice, et tous ceux dont le coeur est droit l&#39;approuveront. 16 qui se lèvera pour moi contre les méchants? qui me soutiendra contre ceux qui font le mal? 17 si l&#39;éternel n&#39;était pas mon secours, mon âme serait bien vite dans la demeure du silence. 18 quand je dis: mon pied chancelle! ta bonté, ô éternel! me sert d&#39;appui. 19 quand les pensées s&#39;agitent en foule au dedans de moi, tes consolations réjouissent mon âme. 20 les méchants te feraient-ils siéger sur leur trône, eux qui forment des desseins iniques en dépit de la loi? 21 ils se rassemblent contre la vie du juste, et ils condamnent le sang innocent. 22 mais l&#39;éternel est ma retraite, mon dieu est le rocher de mon refuge. 23 il fera retomber sur eux leur iniquité, il les anéantira par leur méchanceté; l&#39;éternel, notre dieu, les anéantira. <br><br>et toute la création dit :<br>«oui et amen !»
# , Error: The expanded size of the tensor (638) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 638].  Tensor sizes: [1, 514]
# Error processing text: ne vous attaquez pas sans discernement quand vous faites face à une opinion contraire. <br><br><br>franklin nyamsi dit avoir tiré des leçons des échecs du passé. <br>et c&#39;est l&#39;analyse du passé qui lui a permis d&#39;avoir sa nouvelle posture par<br>je suis d&#39;aucune formation politique. mais j&#39;écoute tout le monde. <br>je ne suis pas pour l&#39;insurrection. <br>mais je suis d&#39;accord avec lui et vais même plus loin en pensant que le système va faire  tout pour empêcher qu&#39;un acteur du changement gagne une élection présidentielle ne serait-ce que dans les urnes.<br>c&#39;est ce à quoi élécam s&#39;emploie actuellement. d&#39;où la non-publication de la liste électorale.<br>il faudra éviter des avc.<br>l&#39;avertissement de nyamsi est utile s&#39;il n&#39;est  pas accompagné d&#39;attaque d&#39;un leader.<br><br>sans liste électorale, une grande majorité d&#39;électeurs favorables au changement ne pourront pas connaître leur  bureau  de vote le jour du scrutin . pendant ce temps, les partisans de rdpc vont aller sans hésitation voter dans leur bureau connu à l&#39;avance.<br> élécam ne pourra même  pas du train où vont les choses, donner l&#39;occasion à un autre candidat que p.b de  gagner l&#39;élection dans les urnes. <br>les électeurs favorables aux changement sont majoritaires. c&#39;est indéniable. mais même s&#39;ils ont la carte de vote beaucoup d&#39;entre eux ne sauront où se trouvent leurs bureaux de vote.<br>c&#39;est pourquoi ils ne veulent pas publier la liste électorale à temps. <br>si élécam finit par publier, ce sera à un moment où personne n&#39;aura  le temps de vérifier son nom et son bureau de vote avant le jour du scrutin.<br>nous mettons de côté les autres formes de tricherie.<br>cela suffit au rdpc pour gagner dans les urnes.<br> ils vont éloigner des électeurs de leur bureaux de vote s&#39;il sont dans la liste. rdpc  aura beau jeu d&#39;accuser les forces de changement d&#39;avoir découragé leurs électeurs par les soupçons de fraudes et la demande de publication de la liste.<br><br>j&#39;habite le cameroun et j&#39;ai déjà été victime de la manipulation de bureau de vote. c&#39;est stressant toute la journée de scrutin.<br>s&#39;il n&#39;a pas de liste  accessible à tous les candidats, il serait mieux qu&#39;il n&#39;y ait pas d&#39;élection . <br>qu&#39;on ne nous affuble par une mascarade.
# , Error: The expanded size of the tensor (629) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 629].  Tensor sizes: [1, 514]
# language
# fr         10375
# en           467
# it           308
# sw           249
# hi           249
# ur           131
# nl            66
# tr            61
# pt            60
# es            21
# Unknown       15
# de            12
# bg             6
# pl             5
# el             4
# ar             1
# ru             1
# vi             1
# th             1
# Name: count, dtype: int64

# %%
print(language_counts)
# Out:
# language
# fr         10375
# en           467
# it           308
# sw           249
# hi           249
# ur           131
# nl            66
# tr            61
# pt            60
# es            21
# Unknown       15
# de            12
# bg             6
# pl             5
# el             4
# ar             1
# ru             1
# vi             1
# th             1
# Name: count, dtype: int64
